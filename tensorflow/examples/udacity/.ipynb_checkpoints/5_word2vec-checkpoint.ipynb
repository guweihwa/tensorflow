# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  f = zipfile.ZipFile(filename)
  print("f.namelist() len=", len(f.namelist()))
  for name in f.namelist():
    print("name=", name)
    return tf.compat.as_str(f.read(name)).split()
  f.close()
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# f.namelist() len= 1
# name= text8
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
  dictionary = dict()
  print("len(dictionary)=", len(dictionary))
  for word, _ in count:
    dictionary[word] = len(dictionary)
    
  print("len(dictionary)=", len(dictionary))
  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# len(dictionary)= 0
# len(dictionary)= 50000
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5239, 3084, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['a', 'originated', 'anarchism', 'term', 'term', 'originated', 'as', 'of']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in xrange(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in xrange(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.311816
# Nearest to was: implanted, expel, secession, analytics, mig, tryptophan, mead, misc,
# Nearest to during: speyer, almost, juror, kann, percent, craze, scandal, sadc,
# Nearest to a: acknowledgment, cricetulus, occupied, sverdlovsk, diet, nanotubes, another, genes,
# Nearest to this: yhwh, fireman, icmp, mycenae, brassiere, origination, optimisation, aristocracy,
# Nearest to years: bungalow, loyal, satisfactory, pdp, disputation, obituaries, conservative, overarching,
# Nearest to that: stephanie, papert, struck, stairs, cowley, hesitation, masses, atonal,
# Nearest to about: assimilated, bata, pullback, malpighi, neglecting, letters, reborn, observables,
# Nearest to two: zseries, aggressively, trout, kekul, renovations, unusual, offenses, ingalls,
# Nearest to three: bird, macgregor, magnetosphere, krishna, quicker, synchronization, choctaws, emma,
# Nearest to after: denison, entirely, romano, kvac, wort, fittingly, maximilian, quadra,
# Nearest to used: reviving, constance, plead, peloponnesian, absorber, realists, rocket, starches,
# Nearest to see: geschichte, pringle, rojas, ramzi, decrypt, militiamen, puppetry, capac,
# Nearest to to: iowa, kibaki, sardinian, regretted, maoists, cavour, rudyard, maharal,
# Nearest to world: documented, jagiello, writings, eniac, barat, reforms, keyed, dorset,
# Nearest to such: zilog, asean, paralysis, impending, salish, paleontologist, mercury, piecewise,
# Nearest to the: massacred, aelia, dependency, floorball, affect, beatles, deposit, amalric,
# Average loss at step 2000: 4.359022
# Average loss at step 4000: 3.862926
# Average loss at step 6000: 3.791528
# Average loss at step 8000: 3.684062
# Average loss at step 10000: 3.615069
# Nearest to was: is, had, been, has, by, were, arlo, antelope,
# Nearest to during: speyer, kann, scandal, before, deontological, in, baseball, greyhound,
# Nearest to a: the, vernon, another, acknowledgment, penny, every, their, stimulated,
# Nearest to this: it, the, which, an, trygve, arnhem, fanzine, volley,
# Nearest to years: bungalow, loyal, bbl, satisfactory, tele, clinically, conservative, slashes,
# Nearest to that: which, same, it, elven, microseconds, cigarettes, stairs, this,
# Nearest to about: learns, glittering, observables, issachar, pullback, reborn, klaus, lancashire,
# Nearest to two: three, four, five, eight, six, seven, zero, nine,
# Nearest to three: four, seven, five, six, eight, two, nine, zero,
# Nearest to after: romano, motley, profiling, divinely, before, infiltration, appreciating, neglects,
# Nearest to used: reviving, will, oblast, deutsche, starches, malibu, plead, powerpoint,
# Nearest to see: geschichte, savants, corvinus, alligators, powder, minted, closer, sheaf,
# Nearest to to: would, undersecretary, birthstone, iowa, gallus, will, rudyard, can,
# Nearest to world: writings, reforms, morphisms, mammalian, peerless, jagiello, pantera, cause,
# Nearest to such: well, impending, reinforce, powder, ulmanis, liberia, porter, bloc,
# Nearest to the: a, its, his, their, this, an, penny, reforestation,
# Average loss at step 12000: 3.602964
# Average loss at step 14000: 3.569784
# Average loss at step 16000: 3.401819
# Average loss at step 18000: 3.459187
# Average loss at step 20000: 3.537391
# Nearest to was: is, were, had, has, be, been, by, forearm,
# Nearest to during: in, at, before, by, on, kann, speyer, genius,
# Nearest to a: another, the, vernon, any, no, alcoholic, acknowledgment, this,
# Nearest to this: which, it, what, the, prone, origination, that, molly,
# Nearest to years: gysin, bbl, bungalow, loyal, satisfactory, nicolas, slashes, year,
# Nearest to that: which, same, but, this, when, it, garz, restitution,
# Nearest to about: learns, pullback, glittering, reborn, letters, observables, lancashire, romanis,
# Nearest to two: three, four, five, six, eight, seven, one, zero,
# Nearest to three: four, six, two, five, seven, eight, zero, nine,
# Nearest to after: before, romano, while, for, motley, profiling, beckett, when,
# Nearest to used: oblast, known, treated, cosgrave, seen, reviving, fasts, powerpoint,
# Nearest to see: minted, savants, can, realignment, tile, litres, obstacles, alligators,
# Nearest to to: will, can, would, may, not, rudyard, for, could,
# Nearest to world: mammalian, pantera, morphisms, writings, reforms, genital, peerless, rambla,
# Nearest to such: well, known, hoddle, other, ulmanis, these, powder, bloc,
# Nearest to the: its, their, his, this, any, a, reforestation, keystroke,
# Average loss at step 22000: 3.501635
# Average loss at step 24000: 3.492276
# Average loss at step 26000: 3.479036
# Average loss at step 28000: 3.480822
# Average loss at step 30000: 3.498766
# Nearest to was: is, were, had, has, been, became, when, arlo,
# Nearest to during: in, before, after, at, cretinism, targeted, kann, greyhound,
# Nearest to a: another, jojo, any, every, stimulated, no, acknowledgment, bagpipes,
# Nearest to this: which, it, what, that, volley, prone, any, southerners,
# Nearest to years: gysin, year, months, days, decades, milan, bbl, times,
# Nearest to that: which, but, what, this, when, thus, however, pontic,
# Nearest to about: within, atm, romanis, observables, glittering, pundit, learns, letters,
# Nearest to two: three, four, one, five, seven, eight, six, nine,
# Nearest to three: five, four, two, seven, eight, six, nine, zero,
# Nearest to after: before, during, when, while, in, for, from, motley,
# Nearest to used: known, treated, found, cosgrave, seen, oblast, competing, powerpoint,
# Nearest to see: tile, savants, minted, realignment, mellow, clues, krag, simplistic,
# Nearest to to: would, can, will, iowa, could, convolution, not, must,
# Nearest to world: morphisms, mammalian, pantera, previous, genital, rambla, compulsive, startled,
# Nearest to such: well, these, known, hoddle, many, other, are, some,
# Nearest to the: their, its, his, any, some, reforestation, these, duomo,
# Average loss at step 32000: 3.502708
# Average loss at step 34000: 3.491415
# Average loss at step 36000: 3.456569
# Average loss at step 38000: 3.298367
# Average loss at step 40000: 3.427635
# Nearest to was: is, had, were, has, became, been, be, arlo,
# Nearest to during: after, before, oedipus, at, when, cretinism, since, in,
# Nearest to a: another, the, stimulated, bombard, bagpipes, any, vernon, every,
# Nearest to this: which, it, that, the, what, any, loxodonta, hoof,
# Nearest to years: days, months, decades, year, gysin, bbl, times, algeria,
# Nearest to that: which, what, this, magyars, it, however, berman, same,
# Nearest to about: over, romanis, learns, seneca, pundit, humanly, pullback, balto,
# Nearest to two: four, three, five, six, seven, one, eight, nine,
# Nearest to three: four, five, two, six, seven, eight, nine, one,
# Nearest to after: before, during, while, when, was, nerves, freitas, romano,
# Nearest to used: known, treated, referred, found, able, seen, described, held,
# Nearest to see: can, savants, correction, list, enthusiastically, etymology, prophylactic, waltrip,
# Nearest to to: will, can, occasioned, could, horne, must, kibaki, gallus,
# Nearest to world: mammalian, pantera, season, clipped, morphisms, previous, overflowing, startled,
# Nearest to such: well, these, known, hoddle, bickering, bloc, infertile, other,
# Nearest to the: its, their, a, his, this, duomo, any, keystroke,
# Average loss at step 42000: 3.435049
# Average loss at step 44000: 3.450207
# Average loss at step 46000: 3.448089
# Average loss at step 48000: 3.353191
# Average loss at step 50000: 3.380919
# Nearest to was: is, has, were, had, became, be, been, arlo,
# Nearest to during: after, in, before, when, oedipus, from, cretinism, targeted,
# Nearest to a: another, any, vernon, no, stimulated, campaigner, bagpipes, the,
# Nearest to this: which, it, the, grimm, that, micros, aelia, what,
# Nearest to years: days, months, decades, year, times, gysin, people, milan,
# Nearest to that: which, however, what, but, thus, trilemma, this, who,
# Nearest to about: romanis, gana, on, eritrea, glittering, anatomist, inmate, exported,
# Nearest to two: three, four, six, one, five, eight, seven, nine,
# Nearest to three: six, seven, four, two, eight, five, nine, zero,
# Nearest to after: before, during, when, while, noxious, but, until, nocs,
# Nearest to used: known, treated, referred, described, applied, able, seen, found,
# Nearest to see: structuring, reassert, include, minted, surveillance, langmuir, lynn, list,
# Nearest to to: can, could, may, would, sardinian, must, will, interphase,
# Nearest to world: mammalian, overflowing, clipped, mindless, pantera, distrust, country, alger,
# Nearest to such: well, these, known, many, bloc, hoddle, infertile, powder,
# Nearest to the: their, its, this, his, distances, some, duomo, keystroke,
# Average loss at step 52000: 3.434091
# Average loss at step 54000: 3.423757
# Average loss at step 56000: 3.437850
# Average loss at step 58000: 3.394671
# Average loss at step 60000: 3.392902
# Nearest to was: is, became, had, were, has, been, arlo, be,
# Nearest to during: after, before, in, following, oedipus, throughout, when, broadbent,
# Nearest to a: another, the, any, vernon, amazing, stimulated, bombard, this,
# Nearest to this: it, which, that, some, there, the, however, what,
# Nearest to years: days, decades, months, year, times, gysin, minutes, bbl,
# Nearest to that: which, what, however, this, it, there, often, reductase,
# Nearest to about: romanis, over, regarding, exported, gana, that, feodor, lac,
# Nearest to two: three, four, five, six, one, seven, eight, zero,
# Nearest to three: five, four, six, seven, two, eight, nine, zero,
# Nearest to after: before, during, when, while, following, until, inlay, had,
# Nearest to used: known, referred, written, described, seen, treated, applied, able,
# Nearest to see: list, but, surveillance, include, can, external, goldsmith, lynn,
# Nearest to to: will, sardinian, may, would, can, should, must, might,
# Nearest to world: gladius, mammalian, alger, mindless, civil, distrust, shining, traverses,
# Nearest to such: well, these, many, known, infertile, hoddle, noticeable, bickering,
# Nearest to the: their, its, a, this, any, his, some, cma,
# Average loss at step 62000: 3.235792
# Average loss at step 64000: 3.252857
# Average loss at step 66000: 3.397382
# Average loss at step 68000: 3.391787
# Average loss at step 70000: 3.361904
# Nearest to was: is, had, has, were, became, been, be, saw,
# Nearest to during: after, before, in, throughout, at, following, until, despite,
# Nearest to a: another, the, any, habib, lector, bombard, libertine, amazing,
# Nearest to this: it, which, the, that, qwerty, there, another, what,
# Nearest to years: days, decades, months, year, bbl, times, minutes, milan,
# Nearest to that: which, however, this, but, what, often, garment, where,
# Nearest to about: over, regarding, romanis, exported, cartography, effecting, gana, balto,
# Nearest to two: three, six, four, seven, five, one, eight, zero,
# Nearest to three: six, five, two, seven, four, eight, nine, one,
# Nearest to after: before, during, when, while, until, following, tagged, frisians,
# Nearest to used: known, described, seen, referred, applied, written, treated, required,
# Nearest to see: list, but, include, dresser, pragmatism, and, farms, should,
# Nearest to to: will, would, must, can, should, towards, may, for,
# Nearest to world: shining, mindless, gladius, country, tsui, shoe, rambla, clipped,
# Nearest to such: these, well, many, known, noticeable, certain, opposed, bloc,
# Nearest to the: its, their, this, a, any, gurion, these, some,
# Average loss at step 72000: 3.370753
# Average loss at step 74000: 3.344101
# Average loss at step 76000: 3.317798
# Average loss at step 78000: 3.351865
# Average loss at step 80000: 3.377508
# Nearest to was: is, had, were, became, has, been, being, arlo,
# Nearest to during: after, in, before, despite, when, throughout, lycus, following,
# Nearest to a: another, every, the, vernon, rigdon, any, amazing, bombard,
# Nearest to this: it, which, what, there, the, that, qwerty, some,
# Nearest to years: days, decades, months, year, times, minutes, bbl, centuries,
# Nearest to that: which, however, majorana, but, where, this, what, mood,
# Nearest to about: over, romanis, cartography, pp, cortical, gana, regarding, approximately,
# Nearest to two: three, six, four, seven, one, five, eight, cm,
# Nearest to three: seven, four, six, five, two, eight, nine, one,
# Nearest to after: before, during, when, while, following, in, noxious, though,
# Nearest to used: known, referred, described, written, seen, applied, treated, available,
# Nearest to see: refer, list, include, external, according, seth, tile, heflin,
# Nearest to to: should, would, tianjin, sardinian, interphase, fairchild, cavour, asphyxia,
# Nearest to world: shoe, country, mindless, dostoyevsky, shining, gladius, tsui, livecd,
# Nearest to such: well, these, opposed, certain, known, noticeable, bloc, various,
# Nearest to the: its, their, this, a, his, cma, farmed, lamont,
# Average loss at step 82000: 3.404764
# Average loss at step 84000: 3.410197
# Average loss at step 86000: 3.391751
# Average loss at step 88000: 3.351832
# Average loss at step 90000: 3.360005
# Nearest to was: is, had, became, has, were, be, arlo, while,
# Nearest to during: after, while, before, in, throughout, when, despite, at,
# Nearest to a: vernon, every, tektites, any, kuan, methylation, bombard, impetus,
# Nearest to this: which, it, the, another, some, valentinians, what, cytokines,
# Nearest to years: days, decades, months, year, minutes, times, centuries, hours,
# Nearest to that: which, however, but, what, majorana, generally, damped, experts,
# Nearest to about: regarding, over, on, finlandization, balto, gana, cartography, zoot,
# Nearest to two: three, four, eight, five, six, seven, one, nine,
# Nearest to three: four, two, five, seven, six, eight, nine, zero,
# Nearest to after: before, during, when, while, until, without, through, though,
# Nearest to used: known, referred, applied, seen, described, called, required, able,
# Nearest to see: list, external, refer, lynn, but, includes, references, tile,
# Nearest to to: sardinian, towards, would, will, birthstone, undersecretary, piaget, should,
# Nearest to world: country, shining, past, dostoyevsky, tsui, shoe, rambla, mindless,
# Nearest to such: well, known, these, opposed, certain, treated, bloc, chani,
# Nearest to the: its, this, his, their, another, an, plating, evoking,
# Average loss at step 92000: 3.395794
# Average loss at step 94000: 3.255953
# Average loss at step 96000: 3.355176
# Average loss at step 98000: 3.248005
# Average loss at step 100000: 3.355592
# Nearest to was: is, became, has, were, had, been, arlo, while,
# Nearest to during: after, before, in, throughout, when, despite, until, following,
# Nearest to a: another, the, any, tektites, vernon, bombard, bagpipes, tala,
# Nearest to this: which, it, qwerty, another, what, that, micros, he,
# Nearest to years: decades, days, months, year, times, centuries, minutes, hours,
# Nearest to that: which, however, what, enacts, who, majorana, this, but,
# Nearest to about: finlandization, regarding, around, over, pp, eritrea, chronos, exported,
# Nearest to two: four, five, three, six, seven, eight, one, nine,
# Nearest to three: four, two, six, seven, five, eight, nine, zero,
# Nearest to after: before, during, when, without, while, until, though, for,
# Nearest to used: referred, known, applied, described, seen, available, sold, written,
# Nearest to see: list, external, craftsmen, can, references, includes, refer, kirsten,
# Nearest to to: will, would, could, should, must, hilversum, towards, nu,
# Nearest to world: shining, country, dostoyevsky, mindless, barrett, tsui, shoe, gladius,
# Nearest to such: well, known, these, certain, opposed, many, separate, treated,
# Nearest to the: their, his, its, your, a, some, each, these,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
# %matplotlib inline

def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to Word2Vec is called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---
